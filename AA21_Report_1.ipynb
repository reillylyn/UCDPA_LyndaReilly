# %%
#import pandas, numpy, seaborn and matplotlib 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#import csv file AA21
AA21 = pd.read_csv ('AA21_Report_2.csv')

#see head 
AA21.head()
# Out:
#                                 Account  Total Turnover 2019  ETT 2019  \
# 0  Trinity College Dublin Book Of Kells             18334000  18334000
# 1               Kylemore Abbey & Garden              7392350   7392350
# 2            House of Waterford Crystal              7247027   7247027
# 3              Blarney Castle & Gardens              6154890   6001178
# 4              Saint Patricks Cathedral              6333463   5081806
#
#    Funding Key Information 1         County
# 0   800000       Attractions     Co. Dublin
# 1   368034       Attractions     Co. Galway
# 2   362351       Attractions  Co. Waterford
# 3   300059       Attractions       Co. Cork
# 4   254090       Attractions     Co. Dublin

# %%
AA21 = AA21.rename({'Key Information 1': 'Cohort'}, axis=1)
AA21.head()
# Out:
#                                 Account  Total Turnover 2019  ETT 2019  \
# 0  Trinity College Dublin Book Of Kells             18334000  18334000
# 1               Kylemore Abbey & Garden              7392350   7392350
# 2            House of Waterford Crystal              7247027   7247027
# 3              Blarney Castle & Gardens              6154890   6001178
# 4              Saint Patricks Cathedral              6333463   5081806
#
#    Funding       Cohort         County
# 0   800000  Attractions     Co. Dublin
# 1   368034  Attractions     Co. Galway
# 2   362351  Attractions  Co. Waterford
# 3   300059  Attractions       Co. Cork
# 4   254090  Attractions     Co. Dublin

# %%
fig, ax = plt.subplots()
ax.bar(AA21.index, AA21['Cohort'])
plt.show()

# %%
sns.countplot(y="Account", data=AA21)
plt.show()

# %%
sns.countplot(y="Cohort", data=AA21)
plt.show()

# %%
sns.countplot(x='Cohort', data=AA21)
plt.show()

# %%
sns.countplot(y='Cohort', data=AA21)
plt.show()

# %%
sns.countplot(x='Cohort', data=AA21)
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style('darkgrid')
sns.set_context('paper')
sns.catplot(x="Cohort", y="Funding", 
            data=AA21,
            kind="box")
plt.xticks(rotation=45)

plt.show()

# %%
fig, ax = plt.subplots()

# Add a boxplot for the "Height" column in the DataFrames
ax.boxplot([AA21["Funding"]])

# Add x-axis tick labels:
ax.set_xticklabels(["Cohort"])

# Add a y-axis label
ax.set_ylabel("Funding")

plt.show()

# %%
sns.distplot(AA21['Funding'],
             hist=False,
             rug=True,
             kde_kws={'shade':True})

# Plot the results
plt.show()

# %%
AA21_4 = pd.read_csv ('AA21_Report_4.csv')

#see head 
AA21_4.head()
# Out:
#                                        Account  Total Turnover 2019  ETT 2019  \
# 0                 International Fishing Centre               175628    175628
# 1  Caherconnell Fort & Sheepdog Demonstrations               541682    541681
# 2                            The Burren Centre               181500    181500
# 3            CLARE HERITAGE & GENEALOGY CENTRE               127137     82419
# 4                     Hazel Mountain Chocolate               953064     52637
#
#    Funding                  Key Information 1     County Region
# 0     8781  Outdoor Tourism Activity Provider  Co. Cavan    IHH
# 1    27070                        Attractions  Co. Clare    WAW
# 2    13165                        Attractions  Co. Clare    WAW
# 3     4121                        Attractions  Co. Clare    WAW
# 4     2632                        Attractions  Co. Clare    WAW

# %%
AA21_4.shape
# Out:
# (164, 7)

# %%
AA21_4 = AA21_4.rename({'Key Information 1': 'Cohort'}, axis=1)
AA21_4.head()
# Out:
#                                        Account  Total Turnover 2019  ETT 2019  \
# 0                 International Fishing Centre               175628    175628
# 1  Caherconnell Fort & Sheepdog Demonstrations               541682    541681
# 2                            The Burren Centre               181500    181500
# 3            CLARE HERITAGE & GENEALOGY CENTRE               127137     82419
# 4                     Hazel Mountain Chocolate               953064     52637
#
#    Funding                             Cohort     County Region
# 0     8781  Outdoor Tourism Activity Provider  Co. Cavan    IHH
# 1    27070                        Attractions  Co. Clare    WAW
# 2    13165                        Attractions  Co. Clare    WAW
# 3     4121                        Attractions  Co. Clare    WAW
# 4     2632                        Attractions  Co. Clare    WAW

# %%
# Create a regression plot with multiple rows
sns.lmplot(data=AA21_4,
           x="Cohort",
           y="Funding",
           row="Region", 
         )

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipykernel_363/3991625585.py in <module>
#       1 # Create a regression plot with multiple rows
# ----> 2 sns.lmplot(data=AA21_4,
#       3            x="Cohort",
#       4            y="Funding",
#       5            row="Region",
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.set_style('darkgrid')
sns.set_context('paper')



sns.catplot(x="Cohort", y="Funding", 
            data=AA21_4,
            kind="box",
           row='Region')
plt.xticks(rotation=45)



plt.show()

# %%
sns.set_style('darkgrid')
sns.set_context('paper')


sns.catplot(x="Cohort", y="Funding", 
            data=AA21_4,
            kind="bar",
           col='Region')
plt.xticks(rotation=45)



plt.show()

# %%
for style in ['white', 'dark', 'whitegrid', 'darkgrid', 'ticks']:
    sns.set_style(style)
    sns.distplot(AA21_4['Funding'])
    sns.despine(left=True)

plt.show()

# %%
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.set_style('darkgrid')
    sns.displot(AA21_4['Funding'])

# %%
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.set_style('darkgrid')
    sns.palplot(sns.color_palette())
    plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(AA21_4['ETT 2019'], color='m')
# Out:
# <AxesSubplot:xlabel='ETT 2019', ylabel='Density'>

# %%
AA21_4 = pd.DataFrame(AA21_4)
print (AA21_4)
print (AA21_4.dtypes)
# Out:
#                                                Account  Total Turnover 2019  \
# 0                         International Fishing Centre               175628
# 1          Caherconnell Fort & Sheepdog Demonstrations               541682
# 2                                    The Burren Centre               181500
# 3                    CLARE HERITAGE & GENEALOGY CENTRE               127137
# 4                             Hazel Mountain Chocolate               953064
# ..                                                 ...                  ...
# 159                         Footfalls Walking Holidays               866830
# 160                           Clissmann Horse Caravans               122952
# 161  GALZGONEWILD ADVENTURES LTD t/a Galzgonewild A...               125048
# 162                         Brennanstown Riding School               500909
# 163                                  The European Club              1277508
#
# ...

# %%
AA21_4['Cohort'] = AA21_4['Cohort'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_363/4115692304.py in <module>
# ----> 1 AA21_4['Cohort'] = AA21_4['Cohort'].astype(float)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(7, 4))

sns.distplot(AA21_4['Funding'], ax=ax0)
sns.distplot(AA21_4.query('Region=="DUBLIN"')['Funding'], ax=ax1)

ax1.set(xlabel='Total_Funding')
ax1.axvline(x=800000, label='Region', linestyle ='--')
ax1.legend()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(7, 4))

sns.distplot(AA21_4['Funding'], ax=ax0)
sns.distplot(AA21_4.query('Cohort=="Attractions"')['Funding'], ax=ax1)

ax1.set(xlabel='Total_Funding', xlim=(0,7000))
ax1.axvline(x=20000, label='Attractions', linestyle ='--')
ax1.legend()

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of 1 bedroom rents
sns.distplot(AA21_4['Funding'], ax=ax)

# Modify the properties of the plot
ax.set(xlabel="Funding",
       xlim=(100, 1500),
       Title="Funding by Region")

# Display the plot
plt.show()

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of 1 bedroom rents
sns.distplot(AA21_4['Funding'], ax=ax)

# Modify the properties of the plot
ax.set(xlabel="Funding",
       Title="Funding Paid")

# Display the plot
plt.show()

# %%
AA21_4["Funding"].mean()
# Out:
# 35170.365853658535

# %%
AA21_4["Funding"].median()
# Out:
# 9627.5

# %%
# Create a figure and axes. Then plot the data
fig, ax = plt.subplots()
sns.distplot(AA21_4['Funding'], ax=ax)

# Customize the labels and limits
ax.set(xlabel="Funding", xlim=(2000,100000), title="AA 2021 Total Funding")

# Add vertical lines for the median and mean
ax.axvline(x=median, color='m', label='Median', linestyle='--', linewidth=2)
ax.axvline(x=mean, color='b', label='Mean', linestyle='-', linewidth=2)

# Show the legend and plot the data
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_363/1082616556.py in <module>
#       7
#       8 # Add vertical lines for the median and mean
# ----> 9 ax.axvline(x=median, color='m', label='Median', linestyle='--', linewidth=2)
#      10 ax.axvline(x=mean, color='b', label='Mean', linestyle='-', linewidth=2)
#      11
#
# NameError: name 'median' is not defined

# %%
# Create a figure and axes. Then plot the data
fig, ax = plt.subplots()
sns.countplot(AA21_4['Funding'], ax=ax)

# Customize the labels and limits
ax.set(xlabel="Funding", xlim=(2000,100000), title="AA 2021 Total Funding")

# Add vertical lines for the median and mean
ax.axvline(x=median, color='m', label='Median', linestyle='--', linewidth=2)
ax.axvline(x=mean, color='b', label='Mean', linestyle='-', linewidth=2)

# Show the legend and plot the data
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_363/199379751.py in <module>
#       7
#       8 # Add vertical lines for the median and mean
# ----> 9 ax.axvline(x=median, color='m', label='Median', linestyle='--', linewidth=2)
#      10 ax.axvline(x=mean, color='b', label='Mean', linestyle='-', linewidth=2)
#      11
#
# NameError: name 'median' is not defined

# %%
# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True)

# Plot the distribution of Funding on ax0
sns.distplot(AA21_4['Funding'], ax=ax0)
ax0.set(xlabel="Funding", xlim=(2000,200000))

# Plot the distribution of ETT in 2019 on ax1
sns.distplot(AA21_4['ETT 2019'], ax=ax1)
ax1.set(xlabel="ETT 2019", xlim=(2000,200000))

# Display the plot
plt.show()

# %%
sns.swarmplot(data=AA21_4, y='Cohort', x='Funding')


plt.show()

# %%
sns.boxplot(data=AA21_4, y='Cohort', x='Funding')


plt.show()

# %%
sns.violinplot(data=AA21_4, y='Cohort', x='Funding')


plt.show()

# %%
sns.barplot(data=AA21_4, y='Cohort', x='Funding', hue='Region')


plt.show()

# %%
sns.pointplot(data=AA21_4, y='Cohort', x='Funding', hue='Region')


plt.show()

# %%
sns.countplot(data=AA21_4, y='Cohort', hue='Region')


plt.show()

# %%
sns.stripplot(data=AA21_4, y='Cohort', x='Funding', hue='Region', jitter=True)


plt.show()

# %%
sns.barplot(data=AA21_4, y='Region', x='Funding', hue='Cohort')


plt.show()

# %%
sns.pointplot(data=AA21_4, y='Region', x='Funding', hue='Cohort', capsize=.1)


plt.show()

# %%
sns.boxplot(data=AA21_4, y='Funding', x='Cohort', hue='Region')
plt.xticks(rotation=45)


plt.show()

# %%
sns.barplot(data=AA21_4, y='Region', x='Funding', hue='Cohort', palette='Paired')


plt.show()

# %%
sns.countplot(data=AA21_4, x='Region', hue='Cohort', palette='Greens')


plt.show()

# %%
sns.regplot(data=AA21_4, x='Region', y='Cohort', marker='+')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipykernel_363/3533407204.py in <module>
# ----> 1 sns.regplot(data=AA21_4, x='Region', y='Cohort', marker='+')
#       2 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
sns.regplot(data=AA21_4, x='Region', y='Funding', marker='+')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipykernel_363/2402235817.py in <module>
# ----> 1 sns.regplot(data=AA21_4, x='Region', y='Funding', marker='+')
#       2 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
# The final plot should include a line using a 2nd order polynomial
sns.regplot(data=AA21_4,
            y='Funding',
            x="ETT 2019",
            x_bins=5,
            order=2)

plt.show()
plt.clf()

# %%
# Display the residual plot
sns.residplot(data=AA21_4,
          y='Funding',
          x="ETT 2019",
          color='g')

plt.show()
plt.clf()

# %%
sns.regplot(data=AA21_4,
          y='Funding',
          x="ETT 2019",
          color='g',
          x_bins=8)
plt.show()

# %%
#matrix plot (heat plots?)

pd.crosstab(AA21_4['Cohort'], AA21_4['Region'],
values=AA21_4['Funding'], aggfunc='mean').round(0)
# Out:
# Region                               DUBLIN      IAE      IHH      WAW
# Cohort
# Attractions                        128288.0  75644.0   6244.0  35421.0
# Outdoor Tourism Activity Provider   14417.0   9778.0  12270.0  11010.0
# Tourism Boat Tour Operators          4381.0      NaN  16791.0  11981.0
# Tourism Golf Courses                82427.0  48556.0      NaN  69586.0

# %%
#showing heatmap where colour is lighter as funding amount is increased 

sns.heatmap(pd.crosstab(AA21_4['Cohort'], AA21_4['Region'],
values=AA21_4['Funding'], aggfunc='mean'))
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Cohort'>

# %%
#customising heatmap 

sns.heatmap(pd.crosstab(AA21_4['Funding'], AA21_4['Region'],
values=AA21_4['Funding'], aggfunc='mean'), annot=True, fmt='str', cmap='YlGnBu', cbar=False, linewidths=.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_363/2553192954.py in <module>
#       1 #customising heatmap
#       2
# ----> 3 sns.heatmap(pd.crosstab(AA21_4['Cohort'], AA21_4['Region'],
#       4 values=AA21_4['Funding'], aggfunc='mean'), annot=True, fmt='str', cmap='YlGnBu', cbar=False, linewidths=.5)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     546     if square:
# ...

# %%
#customising heatmap 

sns.heatmap(pd.crosstab(AA21_4['Region'], AA21_4['Funding'],
values=AA21_4['ETT 2019'], aggfunc='mean'), annot=True, fmt='str', cmap='GnBu', cbar=False, linewidths=.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_363/712045594.py in <module>
#       1 #customising heatmap
#       2
# ----> 3 sns.heatmap(pd.crosstab(AA21_4['Region'], AA21_4['Funding'],
#       4 values=AA21_4['ETT 2019'], aggfunc='mean'), annot=True, fmt='str', cmap='GnBu', cbar=False, linewidths=.5)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     546     if square:
# ...

# %%
g=sns.FacetGrid(AA21_4, col='Cohort')
g.map(sns.boxplot, 'Funding')

plt.show()

# %%
#show as factorplot 

sns.factorplot(x='Funding', data=AA21_4, col='Cohort', kind='box')
plt.show()

# %%
#Facet Grid for regression
g=sns.FacetGrid(AA21_4, col='Cohort')
g.map=(sns.pointplot, 'Funding', 'EET 2019')

plt.show()

# %%
#show as factorplot 

sns.factorplot(x='Funding', data=AA21_4, col='Cohort', kind='point')
plt.show()

# %%
#show a PairGrid for ETT 2019 and Funding in A&A 2021
g=sns.PairGrid(AA21_4, vars=['ETT 2019', 'Funding'])
g=g.map(plt.scatter)

plt.show()

# %%
#show a PairGrid for ETT 2019 and Funding in A&A 2021. Customise
g=sns.PairGrid(AA21_4, vars=['ETT 2019', 'Funding'])

g=g.map_diag(plt.hist)
g=g.map_offdiag(plt.scatter)
plt.show()

# %%
#shortcut function 

sns.pairplot(AA21_4, vars=['Funding', 'Total Turnover 2019'], kind='scatter', hue='Region')
plt.show()

# %%
#shortcut function 

sns.pairplot(AA21_4, vars=['Funding', 'ETT 2019'], kind='scatter', hue='Cohort')
plt.show()

# %%
#shortcut function - lets see TT v ETT 2019

sns.pairplot(AA21_4, vars=['ETT 2019', 'Total Turnover 2019'], kind='scatter', hue='Region')
plt.show()

# %%
#advanced join - on this data -might not show anything! 

g=sns.JointGrid(data=AA21_4, x='ETT 2019',  y='Funding')
g=g.plot_joint(sns.kdeplot)
g=g.plot_marginals(sns.kdeplot, shade=True)
g=g.annotate(stats.pearsonr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_204/2105882586.py in <module>
#       4 g=g.plot_joint(sns.kdeplot)
#       5 g=g.plot_marginals(sns.kdeplot, shade=True)
# ----> 6 g=g.annotate(stats.pearsonr)
#
# AttributeError: 'JointGrid' object has no attribute 'annotate'

# %%
#shortcut of above with jointplot()
sns.jointplot(data=AA21_4, x='ETT 2019', y='Funding', kind='hex')

# %%
sns.distplot(data=AA21_4, x='Cohort')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_204/2620153288.py in <module>
# ----> 1 sns.distplot(data=AA21_4, x='Cohort')
#
# TypeError: distplot() got an unexpected keyword argument 'data'
